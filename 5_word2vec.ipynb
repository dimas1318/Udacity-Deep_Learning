# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5242, 3082, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'originated', 'term', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-59-01669d5c739a>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 6.912669
# Nearest to would: wars, sundown, solace, provocation, dexterity, tleilax, turpentine, khaldun,
# Nearest to th: aircraft, ghosting, strived, escoffier, newnode, sane, segmental, halfbakery,
# Nearest to world: psychology, mpg, battle, mozilla, iud, looney, chimes, banaba,
# Nearest to four: delicate, larsen, cpc, brane, canterbury, scholz, nicolay, examination,
# Nearest to an: incas, organizes, supervillain, gulch, musings, carmen, equitable, microcomputer,
# Nearest to has: kevin, arise, serfs, conjunctivitis, jingles, pulitzer, regina, magnitude,
# Nearest to new: masked, william, halves, motorcyclist, eberhard, folly, escorted, ward,
# Nearest to it: ritual, thicknesses, cosby, encyclical, barry, outstripped, looking, xml,
# Nearest to d: survived, lance, multilingual, cord, wargame, portrayal, babur, punchline,
# Nearest to history: dvds, bainbridge, foundations, rcc, stepney, moles, schoolmaster, equalled,
# Nearest to to: poachers, hotspots, fluke, clintons, miracle, mauritius, menachem, ligamentum,
# Nearest to no: milah, modem, misogyny, triangles, overlap, uffizi, wuppertal, discovery,
# Nearest to more: airs, revolutionaries, correctness, moller, buyer, correcting, higher, parking,
# Nearest to but: venona, forgiving, ligamentum, magdalen, attalus, mag, recycling, quechua,
# Nearest to such: encourages, winfield, apollinaire, lye, infusions, universities, outflow, abdominal,
# Nearest to five: heaters, rheingold, hexadecimal, magnificent, radicalism, syd, enterprising, moses,
# Average loss at step 2000: 4.368417
# Average loss at step 4000: 3.864006
# Average loss at step 6000: 3.791161
# Average loss at step 8000: 3.693809
# Average loss at step 10000: 3.616739
# Nearest to would: may, can, could, will, must, corman, hurry, might,
# Nearest to th: four, ghosting, three, mutton, rivi, middens, escoffier, celebrity,
# Nearest to world: battle, mozilla, slovak, wealthier, pj, queer, current, monocotyledons,
# Nearest to four: eight, six, five, seven, three, two, zero, nine,
# Nearest to an: carmen, incas, circulatory, pauline, realistic, seder, the, larp,
# Nearest to has: had, have, was, is, weaken, become, conjunctivitis, kevin,
# Nearest to new: eberhard, william, marshal, masked, ula, ward, imi, ceuta,
# Nearest to it: he, this, they, which, not, that, there, she,
# Nearest to d: survived, lance, everly, andropov, likely, venous, babur, wrapping,
# Nearest to history: dvds, euripides, burgnich, lithosphere, dynamical, condorcet, tracy, somali,
# Nearest to to: vitae, hawley, tripled, fluke, hotspots, landlords, mauritius, cumulative,
# Nearest to no: it, sicilies, triangles, person, chelsea, braves, dagny, misogyny,
# Nearest to more: moller, revolutionaries, airs, priming, correcting, higher, rather, less,
# Nearest to but: tamarin, hair, could, however, attalus, flaminius, dwan, voortrekkers,
# Nearest to such: well, feat, known, nervousness, rasputin, winfield, encourages, elitism,
# Nearest to five: eight, three, six, four, nine, seven, zero, two,
# Average loss at step 12000: 3.605744
# Average loss at step 14000: 3.574289
# Average loss at step 16000: 3.412803
# Average loss at step 18000: 3.453224
# Average loss at step 20000: 3.537395
# Nearest to would: may, can, could, will, must, might, should, did,
# Nearest to th: ghosting, ravel, masks, celebrity, schiaparelli, three, middens, bureaucracy,
# Nearest to world: battle, u, mozilla, looney, wealthier, computer, coats, annotation,
# Nearest to four: three, eight, six, seven, five, two, nine, zero,
# Nearest to an: baikonur, incas, arno, larp, the, trioxide, carmen, kellogg,
# Nearest to has: had, have, was, is, weaken, warms, does, protectionism,
# Nearest to new: eberhard, marshal, inscribed, ula, attracts, wangenheim, feng, william,
# Nearest to it: he, there, this, which, she, they, not, also,
# Nearest to d: b, lance, revolver, goldstein, trent, andropov, window, sasson,
# Nearest to history: dvds, authentic, tracy, euripides, inhabiting, burgnich, agreed, christa,
# Nearest to to: may, can, could, would, will, hideki, chalker, not,
# Nearest to no: sicilies, survivors, shaken, duress, wendy, a, braves, it,
# Nearest to more: less, revolutionaries, moller, higher, priming, rather, airs, most,
# Nearest to but: however, if, which, and, recently, when, he, that,
# Nearest to such: well, known, elitism, these, feat, rasputin, nervousness, popcorn,
# Nearest to five: six, three, four, eight, two, zero, seven, nine,
# Average loss at step 22000: 3.506419
# Average loss at step 24000: 3.486551
# Average loss at step 26000: 3.485068
# Average loss at step 28000: 3.480708
# Average loss at step 30000: 3.505744
# Nearest to would: may, could, can, will, might, must, should, cannot,
# Nearest to th: ghosting, six, nd, rd, seven, three, two, masks,
# Nearest to world: battle, u, coats, spaulding, computer, mozilla, drowning, kv,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to an: carmen, baikonur, incas, taxonomists, trioxide, plaintiffs, safed, larp,
# Nearest to has: had, have, is, was, warms, having, protectionism, locomotion,
# Nearest to new: ula, eberhard, wahhabism, feng, outlandish, mule, marshal, tak,
# Nearest to it: he, there, this, she, they, never, which, usually,
# Nearest to d: b, lance, goldstein, window, revolver, survived, sasson, kittiwake,
# Nearest to history: dvds, burgnich, inhabiting, tracy, waas, authentic, abdomen, outgrowth,
# Nearest to to: would, vitae, can, fuchs, not, will, landlords, could,
# Nearest to no: any, a, wendy, sicilies, duress, disjoint, silvio, carotene,
# Nearest to more: less, very, most, priming, revolutionaries, higher, airs, moller,
# Nearest to but: however, and, although, which, when, while, if, recently,
# Nearest to such: well, these, known, careers, elitism, other, undergraduate, rasputin,
# Nearest to five: four, seven, six, three, eight, zero, two, nine,
# Average loss at step 32000: 3.504047
# Average loss at step 34000: 3.495830
# Average loss at step 36000: 3.458931
# Average loss at step 38000: 3.300611
# Average loss at step 40000: 3.426651
# Nearest to would: will, may, could, can, might, should, must, cannot,
# Nearest to th: ghosting, nd, renoir, rd, anticipated, transmit, oder, masks,
# Nearest to world: battle, u, wilmut, coats, looney, spaulding, drowning, pilsner,
# Nearest to four: six, three, seven, two, five, eight, nine, one,
# Nearest to an: carmen, baikonur, taxonomists, incas, larp, seder, moabite, dissenters,
# Nearest to has: had, have, was, is, warms, locomotion, jingles, gbu,
# Nearest to new: decision, feng, mulligan, heb, marshal, single, result, kekul,
# Nearest to it: he, there, she, this, they, which, not, but,
# Nearest to d: b, survived, lance, o, c, revolver, goldstein, reilly,
# Nearest to history: dvds, burgnich, tracy, abdomen, inhabiting, inhabitants, abbreviated, fallacies,
# Nearest to to: must, will, can, could, may, vitae, should, patton,
# Nearest to no: any, a, sicilies, carotene, than, still, survivors, duress,
# Nearest to more: less, very, most, revolutionaries, higher, larger, airs, rather,
# Nearest to but: however, and, while, though, it, obeyed, see, although,
# Nearest to such: well, these, known, including, careers, certain, undergraduate, elitism,
# Nearest to five: seven, six, eight, three, four, zero, nine, two,
# Average loss at step 42000: 3.430220
# Average loss at step 44000: 3.448262
# Average loss at step 46000: 3.453294
# Average loss at step 48000: 3.353901
# Average loss at step 50000: 3.385350
# Nearest to would: will, could, can, may, might, should, must, cannot,
# Nearest to th: nd, bc, oder, five, ghosting, bce, escoffier, checkpoints,
# Nearest to world: soviets, spaulding, pilsner, u, battle, curiosity, rivalry, weakening,
# Nearest to four: six, five, eight, seven, three, two, nine, zero,
# Nearest to an: trioxide, larp, baikonur, jacobi, pauline, basayev, carmen, arno,
# Nearest to has: had, have, was, is, does, warms, having, since,
# Nearest to new: heb, toward, single, mulligan, regeneration, memoriam, imi, portable,
# Nearest to it: he, she, there, this, they, eventually, which, then,
# Nearest to d: b, lance, o, survived, c, e, reilly, goldstein,
# Nearest to history: dvds, inhabitants, outgrowth, inhabiting, abbreviated, antidisestablishmentarianism, burgnich, chanson,
# Nearest to to: can, fuchs, angelos, could, may, would, will, kapp,
# Nearest to no: any, duress, only, sicilies, shaken, vy, dbm, little,
# Nearest to more: less, most, very, revolutionaries, larger, higher, rather, greater,
# Nearest to but: however, though, while, although, and, since, when, there,
# Nearest to such: well, these, known, many, certain, careers, undergraduate, elitism,
# Nearest to five: four, six, eight, seven, three, nine, zero, two,
# Average loss at step 52000: 3.433416
# Average loss at step 54000: 3.428822
# Average loss at step 56000: 3.438575
# Average loss at step 58000: 3.394988
# Average loss at step 60000: 3.393237
# Nearest to would: could, will, can, may, might, should, must, cannot,
# Nearest to th: nd, bc, five, ghosting, six, rd, anesthetic, one,
# Nearest to world: soviets, pilsner, rivalry, spaulding, battle, coats, curiosity, opencourseware,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to an: baikonur, larp, knot, pauline, trioxide, arises, carmen, hamid,
# Nearest to has: had, have, was, is, does, having, conjunctivitis, warms,
# Nearest to new: behest, single, toward, heb, ula, mulligan, rojcewicz, bamiyan,
# Nearest to it: he, there, she, this, they, which, what, not,
# Nearest to d: b, c, lance, j, w, reilly, o, expertise,
# Nearest to history: list, theme, mideast, resources, inhabiting, disciplined, district, economy,
# Nearest to to: would, fuchs, vitae, angelos, icq, and, beatboxing, patton,
# Nearest to no: any, exertion, sicilies, duress, vy, oeuvres, little, administering,
# Nearest to more: less, rather, very, most, increasingly, higher, larger, greater,
# Nearest to but: however, and, although, though, see, which, preside, while,
# Nearest to such: well, known, these, certain, many, endless, unqualified, undergraduate,
# Nearest to five: four, six, eight, three, seven, zero, two, nine,
# Average loss at step 62000: 3.238828
# Average loss at step 64000: 3.256529
# Average loss at step 66000: 3.402370
# Average loss at step 68000: 3.393856
# Average loss at step 70000: 3.360253
# Nearest to would: will, could, can, may, might, should, must, cannot,
# Nearest to th: bc, nd, leitrim, ghosting, rd, moyers, one, bce,
# Nearest to world: pilsner, u, rivalry, soviets, spaulding, opencourseware, household, curiosity,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to an: taxonomists, carmen, larp, baikonur, basayev, pauline, arno, seaside,
# Nearest to has: had, have, is, was, since, does, warms, having,
# Nearest to new: behest, single, heterotic, cucurbitaceae, sarcastically, toward, rhondda, assessments,
# Nearest to it: he, there, she, this, they, we, eventually, god,
# Nearest to d: b, lance, w, j, reilly, hypertrophy, nurses, n,
# Nearest to history: list, mideast, dvds, period, sergius, district, segment, friars,
# Nearest to to: will, towards, would, can, samoan, might, fuchs, could,
# Nearest to no: any, little, duress, only, vy, deeply, sicilies, oeuvres,
# Nearest to more: less, most, very, rather, increasingly, higher, too, extremely,
# Nearest to but: however, and, though, although, which, while, than, see,
# Nearest to such: well, these, known, certain, many, unqualified, including, undergraduate,
# Nearest to five: four, six, eight, seven, three, nine, zero, two,
# Average loss at step 72000: 3.375589
# Average loss at step 74000: 3.347117
# Average loss at step 76000: 3.317143
# Average loss at step 78000: 3.348896
# Average loss at step 80000: 3.382170
# Nearest to would: could, will, may, can, might, should, must, cannot,
# Nearest to th: nd, bc, four, oder, leitrim, rd, moyers, ghosting,
# Nearest to world: u, pilsner, spaulding, rivalry, soviets, curiosity, resonating, earliest,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to an: taxonomists, larp, seder, hamid, smilga, moabite, carmen, incas,
# Nearest to has: had, have, is, since, was, warms, protectionism, having,
# Nearest to new: single, mule, cucurbitaceae, wahhabism, imi, expropriation, result, assessments,
# Nearest to it: he, there, she, this, they, we, itself, usually,
# Nearest to d: b, lance, w, expertise, p, j, e, hypertrophy,
# Nearest to history: list, mideast, segment, cladistics, historical, theme, berne, obeys,
# Nearest to to: will, fuchs, would, encephalitis, thurber, dues, arndt, beatboxing,
# Nearest to no: little, any, duress, vy, oeuvres, dbm, sicilies, nothing,
# Nearest to more: less, very, most, rather, larger, higher, too, increasingly,
# Nearest to but: however, although, while, though, and, see, calico, than,
# Nearest to such: well, these, certain, known, nervousness, undergraduate, interrupting, intuitions,
# Nearest to five: four, six, seven, eight, nine, three, zero, two,
# Average loss at step 82000: 3.408085
# Average loss at step 84000: 3.411432
# Average loss at step 86000: 3.390804
# Average loss at step 88000: 3.352163
# Average loss at step 90000: 3.363272
# Nearest to would: could, will, might, can, may, should, must, did,
# Nearest to th: nd, seven, bc, leitrim, eight, oder, moyers, rd,
# Nearest to world: rivalry, pilsner, spaulding, earliest, europe, opencourseware, soviets, rigs,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to an: baikonur, taxonomists, another, trioxide, incas, larp, mishap, knot,
# Nearest to has: had, have, is, was, since, warms, candy, substantial,
# Nearest to new: particular, cucurbitaceae, mule, wahhabism, cruises, different, shortness, single,
# Nearest to it: he, she, there, they, this, itself, eventually, which,
# Nearest to d: b, lance, hypertrophy, punchline, larson, versatility, wargame, mol,
# Nearest to history: list, mideast, obeys, historical, berne, cladistics, semitic, bunch,
# Nearest to to: towards, would, samoan, will, fuchs, authorised, haber, angelos,
# Nearest to no: any, little, nothing, only, freighter, oeuvres, duress, hardly,
# Nearest to more: less, very, most, greater, higher, rather, increasingly, larger,
# Nearest to but: however, and, although, while, which, until, though, that,
# Nearest to such: well, these, certain, known, undergraduate, including, unqualified, nervousness,
# Nearest to five: seven, four, eight, three, six, nine, zero, two,
# Average loss at step 92000: 3.398930
# Average loss at step 94000: 3.255650
# Average loss at step 96000: 3.352457
# Average loss at step 98000: 3.245098
# Average loss at step 100000: 3.358614
# Nearest to would: could, will, might, can, may, should, must, cannot,
# Nearest to th: nd, leitrim, rd, oder, ghosting, third, moyers, dunst,
# Nearest to world: pilsner, spaulding, earliest, rivalry, u, soviets, premiership, resonating,
# Nearest to four: seven, six, five, eight, three, two, nine, zero,
# Nearest to an: another, taxonomists, baikonur, trioxide, mishap, larp, carmen, basayev,
# Nearest to has: had, have, is, was, since, having, warms, gbu,
# Nearest to new: different, cucurbitaceae, single, separate, mule, sith, particular, portable,
# Nearest to it: he, she, this, there, they, often, which, what,
# Nearest to d: b, c, marauders, lance, goldstein, thorns, expertise, j,
# Nearest to history: list, mideast, obeys, receded, historical, endeavours, friars, semitic,
# Nearest to to: will, could, would, should, can, must, towards, chilling,
# Nearest to no: any, little, duress, oeuvres, nothing, freighter, dbm, exertion,
# Nearest to more: less, very, most, higher, greater, larger, too, rather,
# Nearest to but: however, although, and, though, while, until, traveled, than,
# Nearest to such: well, known, certain, these, including, having, undergraduate, many,
# Nearest to five: seven, four, six, eight, three, zero, nine, two,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# ### Switch to CBOW model (just reverse labels)

# %%
data_index = 0
print('data:', [reverse_dictionary[di] for di in data[:8]])
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    labels, batch = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch.reshape(8)])
    print('    labels:', [reverse_dictionary[li] for li in labels])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#     labels: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['originated', 'a', 'term', 'anarchism', 'as', 'originated', 'term', 'of']
#     labels: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_labels, batch_data = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data.reshape(batch_size), train_labels : batch_labels.reshape(batch_size, 1)}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-64-f8239272564b>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.844066
# Nearest to would: satisfying, automatic, midland, levee, predicament, astronautics, desktops, posted,
# Nearest to th: shoals, unseen, earthquakes, robin, hungarian, ships, otc, warned,
# Nearest to world: fainting, sledge, guttural, anteater, ishiro, larva, nx, dedicate,
# Nearest to four: lowly, eliza, oldham, imi, pronoun, dewar, thyroxine, wore,
# Nearest to an: tigre, fledging, matrix, defer, rota, patience, bonn, milestone,
# Nearest to has: docklands, bubba, joyful, ecu, immortality, evangelicalism, slavery, maude,
# Nearest to new: constantius, willi, gohan, castrati, reduplication, bates, spake, milking,
# Nearest to it: schottenheimer, duchess, warner, fresnel, programs, basins, nephritis, freshwater,
# Nearest to d: eyes, anni, frasier, yukio, serum, cie, proc, suspension,
# Nearest to history: aqueous, reinvent, falsifiability, zug, gamespot, jarring, intersputnik, vostok,
# Nearest to to: jubal, dancing, statutory, class, plumage, arrakis, herds, fad,
# Nearest to no: mandola, dodge, sightings, assigns, spectacular, hasse, hatched, lauren,
# Nearest to more: ean, delimitation, malabo, agra, boyfriend, diluted, mistaken, norris,
# Nearest to but: audiovisual, particular, tzu, hosting, protestants, headers, soulful, dheas,
# Nearest to such: ilm, infusion, divide, stabilizers, dziga, stock, pandas, antenna,
# Nearest to five: ditka, kaifu, adverbial, expiring, barreled, marr, mathworld, malaysia,
# Average loss at step 2000: 4.512193
# Average loss at step 4000: 4.119950
# Average loss at step 6000: 3.921919
# Average loss at step 8000: 3.921540
# Average loss at step 10000: 3.887419
# Nearest to would: predicament, automatic, championships, yue, could, will, politically, portrait,
# Nearest to th: nine, seven, six, shoals, kinshasa, joyous, unseen, robin,
# Nearest to world: guttural, artist, fainting, official, lanphier, sara, wei, larva,
# Nearest to four: six, three, eight, zero, five, two, seven, nine,
# Nearest to an: a, the, rota, reciting, s, bracing, tigre, archaeologist,
# Nearest to has: had, have, rally, overt, omnipotent, kaolinite, finest, is,
# Nearest to new: constantius, reduplication, faxes, poplar, methodus, firstborn, angli, bates,
# Nearest to it: he, that, not, forearm, victoria, bihar, whitehead, healey,
# Nearest to d: eyes, anni, yukio, kashrut, immigration, cie, projected, gustave,
# Nearest to history: reinvent, aqueous, zug, westchester, michelson, kimball, valley, rohan,
# Nearest to to: guerrero, by, schoolmaster, statutory, giroux, protium, otherwise, shorten,
# Nearest to no: sanctity, mandola, pkn, ryder, governors, lacked, handicrafts, bipeds,
# Nearest to more: mistaken, iole, neglect, commonly, polish, christians, hungarians, plane,
# Nearest to but: audiovisual, particular, slow, estimates, urges, tt, marathas, and,
# Nearest to such: far, well, infusion, viollet, divide, prokaryote, dziga, sailboat,
# Nearest to five: six, zero, two, eight, nine, three, four, seven,
# Average loss at step 12000: 3.867017
# Average loss at step 14000: 3.837857
# Average loss at step 16000: 3.738268
# Average loss at step 18000: 3.826777
# Average loss at step 20000: 3.791249
# Nearest to would: could, can, should, will, to, predicament, had, may,
# Nearest to th: four, joyous, kinshasa, unseen, six, eight, shoals, ships,
# Nearest to world: sara, haile, monet, app, lanphier, fluent, longest, first,
# Nearest to four: six, five, three, seven, eight, two, zero, nine,
# Nearest to an: a, reciting, this, bonn, greed, satires, rota, chr,
# Nearest to has: had, have, ecclesiastes, is, with, ghali, omnipotent, susceptible,
# Nearest to new: faxes, passion, constantius, sunda, firstborn, leftism, geography, vibrating,
# Nearest to it: this, he, there, that, not, they, still, outlawed,
# Nearest to d: b, UNK, one, william, cie, yasser, apprenticeship, alarmed,
# Nearest to history: reinvent, aqueous, michelson, origins, gyroscopic, aaliyah, lovecraft, lemon,
# Nearest to to: would, asuras, barrett, counterexamples, kushans, prayer, asatru, privilege,
# Nearest to no: any, lacked, mandola, rotunda, rodrigues, sparingly, ryder, acquisitions,
# Nearest to more: christians, neglect, wheaton, semivowel, plane, very, stockhausen, samson,
# Nearest to but: that, inexplicable, booked, cofinal, corporatist, however, balanced, slow,
# Nearest to such: well, known, far, favourites, prokaryote, cpr, sailboat, sza,
# Nearest to five: eight, seven, six, three, four, nine, zero, two,
# Average loss at step 22000: 3.727937
# Average loss at step 24000: 3.788763
# Average loss at step 26000: 3.638619
# Average loss at step 28000: 3.591775
# Average loss at step 30000: 3.632783
# Nearest to would: could, can, should, may, will, to, does, glucose,
# Nearest to th: joyous, eight, six, shoals, kinshasa, mjh, nine, sarasota,
# Nearest to world: sara, haile, app, farthest, winged, chapter, harmonics, wei,
# Nearest to four: five, six, three, two, seven, zero, eight, nine,
# Nearest to an: a, bonn, its, the, nitrox, rota, reciting, bracing,
# Nearest to has: had, have, was, is, beaconsfield, ecclesiastes, microinstruction, susceptible,
# Nearest to new: firstborn, passion, former, constantius, faxes, methodus, leftism, poplar,
# Nearest to it: he, this, there, which, not, they, groove, idm,
# Nearest to d: b, writer, acres, cie, uttar, cognition, abidjan, venturing,
# Nearest to history: origins, main, postel, gyroscopic, ses, pasta, aaliyah, lemon,
# Nearest to to: would, may, can, from, slice, internalism, after, might,
# Nearest to no: any, sparingly, suffering, bj, sorenson, gog, urged, handicrafts,
# Nearest to more: less, very, rather, christians, likely, most, better, neglect,
# Nearest to but: and, when, there, maglev, however, booked, not, they,
# Nearest to such: well, far, known, sza, favourites, cpr, prokaryote, counterpoint,
# Nearest to five: four, six, zero, three, seven, two, eight, nine,
# Average loss at step 32000: 3.664131
# Average loss at step 34000: 3.750658
# Average loss at step 36000: 3.681185
# Average loss at step 38000: 3.719690
# Average loss at step 40000: 3.683015
# Nearest to would: could, may, can, will, should, does, did, to,
# Nearest to th: joyous, sarasota, shoals, mjh, guiding, inadvertently, approximately, unseen,
# Nearest to world: sara, eutyches, winged, trajectory, harmonics, spans, war, felipe,
# Nearest to four: six, three, five, eight, two, zero, seven, one,
# Nearest to an: highgate, cena, nitrox, rota, vivid, greed, reciting, bonn,
# Nearest to has: had, have, was, is, beaconsfield, ghali, corelli, with,
# Nearest to new: firstborn, sunda, constantius, former, passion, methodus, outfield, striking,
# Nearest to it: he, which, this, there, they, but, she, lilac,
# Nearest to d: b, sejm, acres, chariots, prefects, frits, venturing, galatea,
# Nearest to history: beck, main, origins, silks, shoals, steampunk, sophia, outside,
# Nearest to to: would, renfrew, can, may, reilly, carat, radiocommunication, internalism,
# Nearest to no: any, bj, that, this, suffering, rodrigues, however, orser,
# Nearest to more: less, most, very, rather, better, neglect, langerhans, identities,
# Nearest to but: however, stockpiles, mycological, which, it, and, because, when,
# Nearest to such: well, known, far, sza, favourites, as, prokaryote, unsigned,
# Nearest to five: six, three, four, seven, two, zero, eight, nine,
# Average loss at step 42000: 3.681435
# Average loss at step 44000: 3.707805
# Average loss at step 46000: 3.676896
# Average loss at step 48000: 3.748481
# Average loss at step 50000: 3.651548
# Nearest to would: could, may, will, can, should, did, to, does,
# Nearest to th: eight, nine, joyous, bce, bc, seven, kinshasa, sarasota,
# Nearest to world: sara, war, trajectory, harmonics, delved, ertegun, winged, religionfacts,
# Nearest to four: six, five, three, seven, two, eight, zero, one,
# Nearest to an: lumber, this, bracing, bonn, cena, reciting, another, a,
# Nearest to has: had, have, is, was, beaconsfield, since, having, overt,
# Nearest to new: firstborn, former, sunda, geography, guide, york, walpole, filed,
# Nearest to it: he, this, she, there, interpreted, then, only, lilac,
# Nearest to d: b, venturing, bcpl, nine, representational, acres, castro, postmillennialism,
# Nearest to history: india, beck, art, origins, outside, main, ses, violins,
# Nearest to to: would, counterexamples, will, could, accrue, may, for, asuras,
# Nearest to no: any, some, bj, orser, this, equating, a, however,
# Nearest to more: less, rather, very, better, most, knit, so, about,
# Nearest to but: which, however, when, that, though, he, because, and,
# Nearest to such: well, known, sza, cpr, far, favourites, swapped, chungcheong,
# Nearest to five: six, four, three, seven, eight, zero, two, nine,
# Average loss at step 52000: 3.677118
# Average loss at step 54000: 3.757902
# Average loss at step 56000: 3.737881
# Average loss at step 58000: 3.660851
# Average loss at step 60000: 3.719693
# Nearest to would: could, can, will, may, should, did, does, must,
# Nearest to th: nine, bc, six, joyous, four, bce, st, zero,
# Nearest to world: war, sara, lucca, spans, trajectory, marduk, frida, religionfacts,
# Nearest to four: three, five, six, seven, eight, two, zero, nine,
# Nearest to an: lumber, cena, bonn, another, this, the, rota, bracing,
# Nearest to has: had, have, was, is, beaconsfield, having, perished, kl,
# Nearest to new: firstborn, former, filed, striking, submissions, vibrating, constantius, outfield,
# Nearest to it: he, this, there, she, they, bombs, still, widely,
# Nearest to d: b, moslem, institut, pebble, venturing, frits, deathbed, initialized,
# Nearest to history: india, postel, list, culture, beck, violins, origins, stephenson,
# Nearest to to: will, could, can, would, statutory, might, tamers, declining,
# Nearest to no: any, bj, a, still, that, this, another, isn,
# Nearest to more: less, very, rather, better, identities, most, thoroughfares, faster,
# Nearest to but: however, though, because, while, although, and, when, only,
# Nearest to such: well, known, sza, many, these, scorn, searle, placebo,
# Nearest to five: six, three, seven, four, zero, eight, two, one,
# Average loss at step 62000: 3.695836
# Average loss at step 64000: 3.721144
# Average loss at step 66000: 3.527781
# Average loss at step 68000: 3.494814
# Average loss at step 70000: 3.688057
# Nearest to would: could, will, may, should, can, did, does, might,
# Nearest to th: nine, seven, four, st, five, eight, joyous, bce,
# Nearest to world: war, sara, marduk, cup, ribose, lucca, hazy, frida,
# Nearest to four: three, five, seven, six, eight, zero, two, nine,
# Nearest to an: the, a, another, rota, cena, this, lumber, greed,
# Nearest to has: had, have, beaconsfield, is, since, was, having, kl,
# Nearest to new: olympiad, submissions, striking, shri, outfield, former, transforms, triumph,
# Nearest to it: he, this, they, only, that, not, she, but,
# Nearest to d: b, deathbed, frits, UNK, moslem, croft, blasts, h,
# Nearest to history: list, culture, geography, postel, stephenson, external, see, india,
# Nearest to to: will, can, would, must, could, renfrew, declining, may,
# Nearest to no: any, bj, although, only, sparingly, another, still, majorities,
# Nearest to more: less, very, rather, most, better, identities, faster, million,
# Nearest to but: however, though, and, although, only, when, even, because,
# Nearest to such: well, known, sza, as, these, follows, bingu, saddle,
# Nearest to five: seven, four, six, three, eight, zero, two, nine,
# Average loss at step 72000: 3.605168
# Average loss at step 74000: 3.692454
# Average loss at step 76000: 3.613554
# Average loss at step 78000: 3.726452
# Average loss at step 80000: 3.649409
# Nearest to would: will, could, may, should, can, must, might, did,
# Nearest to th: nine, bce, bc, seven, st, four, nd, zero,
# Nearest to world: war, know, sara, hazy, marduk, carotenoids, lucca, ribose,
# Nearest to four: five, three, six, seven, eight, two, zero, nine,
# Nearest to an: rota, greed, another, a, bonn, lumber, reciting, this,
# Nearest to has: had, have, is, beaconsfield, since, was, may, headlining,
# Nearest to new: submissions, striking, london, olympiad, guide, cowboy, nippon, shri,
# Nearest to it: he, there, this, she, they, groove, flipping, that,
# Nearest to d: b, e, atv, f, deathbed, m, k, c,
# Nearest to history: list, culture, stephenson, cleanliness, india, deaths, altruism, slough,
# Nearest to to: can, will, would, must, might, could, slice, minimize,
# Nearest to no: any, another, this, bj, a, trentino, majorities, romain,
# Nearest to more: less, better, very, most, rather, greater, identities, much,
# Nearest to but: however, though, although, because, while, when, even, until,
# Nearest to such: well, known, sza, follows, as, placebo, favourites, moshoeshoe,
# Nearest to five: four, three, six, seven, eight, zero, two, nine,
# Average loss at step 82000: 3.693174
# Average loss at step 84000: 3.637393
# Average loss at step 86000: 3.636568
# Average loss at step 88000: 3.577969
# Average loss at step 90000: 3.584363
# Nearest to would: could, will, should, may, might, can, must, did,
# Nearest to th: bce, st, nd, bc, twentieth, nine, eight, six,
# Nearest to world: marduk, cup, exporter, infiltrated, aliens, war, overbearing, ribose,
# Nearest to four: three, six, five, seven, eight, two, zero, nine,
# Nearest to an: another, a, lumber, reciting, bonn, wahhabism, the, timecode,
# Nearest to has: had, have, having, is, was, beaconsfield, ecclesiastes, since,
# Nearest to new: shri, outfield, guide, york, bitrate, cowboy, older, future,
# Nearest to it: he, this, there, she, only, but, seventy, groove,
# Nearest to d: b, m, f, n, atv, deathbed, c, k,
# Nearest to history: list, culture, trooper, stephenson, external, hall, encyclopedia, article,
# Nearest to to: would, poured, will, could, might, counterexamples, declining, renfrew,
# Nearest to no: any, something, stosunku, another, useless, trentino, however, that,
# Nearest to more: less, most, rather, very, faster, better, neglect, identities,
# Nearest to but: however, though, and, although, when, while, which, because,
# Nearest to such: well, sza, result, favourites, known, follows, medina, swapped,
# Nearest to five: three, six, four, seven, eight, two, zero, nine,
# Average loss at step 92000: 3.657514
# Average loss at step 94000: 3.683210
# Average loss at step 96000: 3.643155
# Average loss at step 98000: 3.707511
# Average loss at step 100000: 3.666933
# Nearest to would: could, will, should, might, may, can, must, did,
# Nearest to th: nine, six, seven, eight, st, twentieth, bce, nd,
# Nearest to world: war, marduk, blah, dysphoria, lucca, recluse, cup, nonstop,
# Nearest to four: six, seven, five, eight, three, two, zero, one,
# Nearest to an: another, reciting, bonn, wahhabism, bracing, this, brutality, lumber,
# Nearest to has: had, have, having, beaconsfield, is, was, became, headlining,
# Nearest to new: york, peres, london, guide, kansas, nippon, abject, firstborn,
# Nearest to it: he, this, she, there, generally, only, they, northampton,
# Nearest to d: b, n, deathbed, f, z, croft, m, bassist,
# Nearest to history: list, india, culture, marital, geography, external, main, see,
# Nearest to to: would, will, accrue, might, anjouan, declining, counterexamples, slice,
# Nearest to no: any, little, only, romain, stosunku, trentino, wired, something,
# Nearest to more: less, rather, very, faster, better, greater, neglect, slightly,
# Nearest to but: although, however, though, there, still, yet, and, while,
# Nearest to such: well, known, many, result, oxidize, sza, medina, imperfection,
# Nearest to five: six, eight, four, three, seven, zero, two, nine,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
