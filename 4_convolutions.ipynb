# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    save = u.load()
    #save = pickle.load(f)
    train_dataset = save['train_dataset']
    train_labels = save['train_labels']
    valid_dataset = save['valid_dataset']
    valid_labels = save['valid_labels']
    test_dataset = save['test_dataset']
    test_labels = save['test_labels']
    del save  # hint to help gc free up memory
    print('Training set', train_dataset.shape, train_labels.shape)
    print('Validation set', valid_dataset.shape, valid_labels.shape)
    print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.797279
# Minibatch accuracy: 0.0%
# Validation accuracy: 9.5%
# Minibatch loss at step 50: 1.809373
# Minibatch accuracy: 31.2%
# Validation accuracy: 37.2%
# Minibatch loss at step 100: 0.730840
# Minibatch accuracy: 81.2%
# Validation accuracy: 53.7%
# Minibatch loss at step 150: 0.952998
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.9%
# Minibatch loss at step 200: 1.775279
# Minibatch accuracy: 56.2%
# Validation accuracy: 73.3%
# Minibatch loss at step 250: 0.412134
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.4%
# Minibatch loss at step 300: 1.128051
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.8%
# Minibatch loss at step 350: 1.181246
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.5%
# Minibatch loss at step 400: 1.378776
# Minibatch accuracy: 56.2%
# Validation accuracy: 79.6%
# Minibatch loss at step 450: 0.708091
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 500: 0.289690
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.8%
# Minibatch loss at step 550: 0.286851
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 600: 0.802569
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 650: 0.674143
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 700: 0.266181
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.4%
# Minibatch loss at step 750: 0.384054
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss at step 800: 1.283888
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.6%
# Minibatch loss at step 850: 0.388032
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# Minibatch loss at step 900: 0.234566
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# Minibatch loss at step 950: 0.879676
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 1000: 0.177680
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# Test accuracy: 89.7%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))

    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))

    layer3_weights = tf.Variable(
        tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))

    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))


    # Model.
    def model(data):
        conv1 = tf.nn.relu(tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME') + layer1_biases)
        pool1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

        conv2 = tf.nn.relu(tf.nn.conv2d(pool1, layer2_weights, [1, 1, 1, 1], padding='SAME') + layer2_biases)
        pool2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

        shape = pool2.get_shape().as_list()
        reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
        fc1 = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(fc1, layer4_weights) + layer4_biases


    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
                valid_prediction.eval(), valid_labels))
    print('Max pool Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-11-e95d2b205454>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 3.189221
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.248517
# Minibatch accuracy: 25.0%
# Validation accuracy: 15.8%
# Minibatch loss at step 100: 1.346860
# Minibatch accuracy: 68.8%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 1.121081
# Minibatch accuracy: 68.8%
# Validation accuracy: 71.8%
# Minibatch loss at step 200: 1.609965
# Minibatch accuracy: 56.2%
# Validation accuracy: 67.3%
# Minibatch loss at step 250: 0.503050
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.0%
# Minibatch loss at step 300: 0.959467
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.9%
# Minibatch loss at step 350: 0.864908
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.4%
# Minibatch loss at step 400: 1.160387
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.0%
# Minibatch loss at step 450: 0.484003
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.9%
# Minibatch loss at step 500: 0.270990
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 550: 0.275767
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 600: 0.677442
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 650: 0.657892
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 700: 0.281933
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.3%
# Minibatch loss at step 750: 0.370441
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.9%
# Minibatch loss at step 800: 1.161133
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.5%
# Minibatch loss at step 850: 0.556983
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 900: 0.382504
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.3%
# Minibatch loss at step 950: 0.728418
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 1000: 0.233338
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.6%
# Max pool Test accuracy: 90.9%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 32
num_hidden = 64
num_steps = 30001

graph = tf.Graph()

with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    global_step = tf.Variable(0)  # count the number of steps taken.

    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))

    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))

    layer3_weights = tf.Variable(
        tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))

    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))


    # Model.
    def model(data, keep_prob):
        conv1 = tf.nn.relu(tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME') + layer1_biases)
        pool1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

        conv2 = tf.nn.relu(tf.nn.conv2d(pool1, layer2_weights, [1, 1, 1, 1], padding='SAME') + layer2_biases)
        pool2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

        shape = pool2.get_shape().as_list()
        reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
        fc1 = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        fc1_drop = tf.nn.dropout(fc1, keep_prob)

        y_conv = tf.nn.softmax(tf.matmul(fc1_drop, layer4_weights) + layer4_biases)

        return y_conv


    # Training computation.
    y_conv = model(tf_train_dataset, 0.5)
    y_ = tf_train_labels
    cross_entropy = tf.reduce_mean(-tf.reduce_sum(y_ * tf.log(y_conv), reduction_indices=[1]))

    loss = cross_entropy + 0.001 * (
        tf.nn.l2_loss(layer3_weights) + tf.nn.l2_loss(layer3_biases) + tf.nn.l2_loss(layer4_weights) + tf.nn.l2_loss(
            layer4_biases))

    # Optimizer.
    learning_rate = tf.train.exponential_decay(1e-1, global_step, num_steps, 0.7, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = y_conv
    valid_prediction = model(tf_valid_dataset, 1.0)
    test_prediction = model(tf_test_dataset, 1.0)

# %%
with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 300 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
                valid_prediction.eval(), valid_labels))
    print('Lenet 5 Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-13-606f7259c558>:2: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 5.763537
# Minibatch accuracy: 6.2%
# Validation accuracy: 9.1%
# Minibatch loss at step 300: 2.504175
# Minibatch accuracy: 31.2%
# Validation accuracy: 54.0%
# Minibatch loss at step 600: 1.276052
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.8%
# Minibatch loss at step 900: 0.976574
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 1200: 1.043805
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 1500: 0.740277
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 1800: 0.656543
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 2100: 0.670001
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 2400: 2.182200
# Minibatch accuracy: 50.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 2700: 1.463192
# Minibatch accuracy: 56.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 3000: 0.750157
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 3300: 0.769507
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 3600: 0.584786
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 3900: 1.080527
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 4200: 1.214969
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.2%
# Minibatch loss at step 4500: 0.758906
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 4800: 0.951604
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 5100: 0.854084
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 5400: 0.597209
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 5700: 0.829661
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 6000: 0.675340
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.9%
# Minibatch loss at step 6300: 0.599632
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 6600: 0.393132
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.8%
# Minibatch loss at step 6900: 1.456640
# Minibatch accuracy: 62.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 7200: 0.576456
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 7500: 0.299182
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 7800: 0.926077
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.4%
# Minibatch loss at step 8100: 0.836196
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 8400: 0.706380
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 8700: 0.395749
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 9000: 0.244582
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 9300: 0.763253
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 9600: 0.452802
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 9900: 0.331119
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 10200: 0.558220
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.8%
# Minibatch loss at step 10500: 0.807889
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 10800: 0.677988
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 11100: 0.318065
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 11400: 0.447834
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 11700: 0.480962
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 12000: 0.606704
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 12300: 0.198305
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# Minibatch loss at step 12600: 0.536724
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 12900: 0.743791
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 13200: 0.622627
# Minibatch accuracy: 68.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 13500: 0.497474
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 13800: 0.248913
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# Minibatch loss at step 14100: 0.786950
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 14400: 0.496207
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.4%
# Minibatch loss at step 14700: 0.182867
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# Minibatch loss at step 15000: 0.691953
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 15300: 0.346783
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 15600: 0.384820
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 15900: 0.423742
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 16200: 0.525743
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 16500: 1.309775
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 16800: 0.560627
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 17100: 0.486790
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 17400: 0.192946
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 17700: 0.424927
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 18000: 0.411595
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 18300: 0.296975
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 18600: 0.208318
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 18900: 0.342782
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 19200: 0.412459
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 19500: 0.583401
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 19800: 0.106375
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# Minibatch loss at step 20100: 0.552836
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.9%
# Minibatch loss at step 20400: 0.258483
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 20700: 0.719277
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 21000: 0.587103
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.3%
# Minibatch loss at step 21300: 0.443320
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 21600: 0.650140
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 21900: 1.325729
# Minibatch accuracy: 68.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 22200: 0.481559
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 22500: 0.270140
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# Minibatch loss at step 22800: 0.545909
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.4%
# Minibatch loss at step 23100: 0.267681
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 23400: 0.440478
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 23700: 0.717996
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 24000: 0.283469
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 24300: 0.569813
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 24600: 0.346555
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 24900: 1.547119
# Minibatch accuracy: 62.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 25200: 0.197992
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 25500: 0.098793
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# Minibatch loss at step 25800: 0.336350
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 26100: 0.528120
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 26400: 0.529256
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.4%
# Minibatch loss at step 26700: 0.489275
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 27000: 0.452002
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 27300: 0.402067
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 27600: 0.486404
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 27900: 0.291967
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 28200: 0.348086
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 28500: 0.377452
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 28800: 0.663151
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 29100: 0.362790
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 29400: 0.523571
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 29700: 0.539100
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.8%
# Minibatch loss at step 30000: 0.100874
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# Lenet 5 Test accuracy: 95.4%
